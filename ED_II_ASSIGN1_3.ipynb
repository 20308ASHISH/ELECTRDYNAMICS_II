# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
a = 1
x = np.linspace(0,1,1000)
y = a/(1-x**2)**0.5
# Out:
# /tmp/ipython-input-1179775810.py:3: RuntimeWarning: divide by zero encountered in divide
#   y = a/(1-x**2)**0.5

# %%
plt.plot(x,y,color='blue')
plt.xlabel("speed in c")
plt.ylabel("the lifetime increment")
z=0
plt.plot(x,0*x+1, color = "red")
plt.show()
